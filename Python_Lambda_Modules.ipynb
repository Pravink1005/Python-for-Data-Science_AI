# %% [markdown]
# # Module 2 - Part 5
# # Lambda Expressions, Modules & Practical Lab

# %% [markdown]
# ## Learning Objectives
# - Use lambda expressions
# - Apply map(), filter(), sorted()
# - Import built-in modules
# - Create custom modules
# - Complete practical exercises

# %% [markdown]
# ## Lambda
#
# Anonymous functions.

# %%
square=lambda x:x*x
print(square(5))

# %% [markdown]
# ### Practice

# %%
# Write your solution here

# %% [markdown]
# ## Lambda with map()
#
# Transform data.

# %%
nums=[1,2,3,4]
print(list(map(lambda x:x*x,nums)))

# %% [markdown]
# ### Practice

# %%
# Write your solution here

# %% [markdown]
# ## Lambda with filter()
#
# Filter data.

# %%
nums=range(10)
print(list(filter(lambda x:x%2==0,nums)))

# %% [markdown]
# ### Practice

# %%
# Write your solution here

# %% [markdown]
# ## Lambda with sorted()
#
# Custom sorting.

# %%
words=['pear','apple','kiwi']
print(sorted(words,key=lambda x:len(x)))

# %% [markdown]
# ### Practice

# %%
# Write your solution here

# %% [markdown]
# ## math Module
#
# Mathematical functions.

# %%
import math
print(math.sqrt(25),math.pi)

# %% [markdown]
# ### Practice

# %%
# Write your solution here

# %% [markdown]
# ## random Module
#
# Generate random values.

# %%
import random
print(random.randint(1,10))

# %% [markdown]
# ### Practice

# %%
# Write your solution here

# %% [markdown]
# ## datetime Module
#
# Current date and time.

# %%
from datetime import datetime
print(datetime.now())

# %% [markdown]
# ### Practice

# %%
# Write your solution here

# %% [markdown]
# ## Import Styles
#
# Different import methods.

# %%
from math import factorial
print(factorial(5))

# %% [markdown]
# ### Practice

# %%
# Write your solution here

# %% [markdown]
# ## Custom Module
#
# Example only.

# %%
# Create mymodule.py
# import mymodule

# %% [markdown]
# ### Practice

# %%
# Write your solution here

# %% [markdown]
# ## Best Practices
#
# Keep modules organized.

# %%
print('Use descriptive names')

# %% [markdown]
# ### Practice

# %%
# Write your solution here

# %% [markdown]
# ## Practical Lab
# Complete:
# 1. Square numbers with map()
# 2. Filter odd numbers
# 3. Random password seed
# 4. Date display
# 5. Sort students by marks

# %% [markdown]
# ## Mini Project
# Create a utility menu using functions and the math module.

# %%
import math
print("Area of Circle:", math.pi*5*5)

# %% [markdown]
# ## Interview Questions
# - What is lambda?
# - Difference between map() and filter()?
# - Why use modules?

# %% [markdown]
# ## Module 2 Summary
# You completed Lists, Tuples, Sets, Dictionaries, Functions, Lambda Expressions, Modules, and Practical Lab.

# %% [markdown]
# ### Extra Practice

# %%
# Practice

# %% [markdown]
# ### Extra Practice

# %%
# Practice

# %% [markdown]
# ### Extra Practice

# %%
# Practice

# %% [markdown]
# ### Extra Practice

# %%
# Practice

# %% [markdown]
# ### Extra Practice

# %%
# Practice

# %% [markdown]
# ### Extra Practice

# %%
# Practice

# %% [markdown]
# ### Extra Practice

# %%
# Practice
