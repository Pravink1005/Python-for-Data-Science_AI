# %% [markdown]
# # Python Dictionaries

# %% [markdown]
# ## Learning Objectives
# - Understand dictionaries
# - Create and update dictionaries
# - Access keys and values
# - Loop through dictionaries
# - Use dictionary methods
# - Write dictionary comprehensions

# %% [markdown]
# ## Introduction to Dictionaries
#
# A dictionary stores data as key-value pairs.

# %%
student={'name':'Alice','age':20}
print(student)

# %% [markdown]
# ### Exercise
# Practice **Introduction to Dictionaries**.

# %%
# Write your solution here

# %% [markdown]
# ## Creating Dictionaries
#
# Create empty and populated dictionaries.

# %%
d={}
emp={'id':101,'name':'John'}
print(d,emp)

# %% [markdown]
# ### Exercise
# Practice **Creating Dictionaries**.

# %%
# Write your solution here

# %% [markdown]
# ## Accessing Values
#
# Access using keys.

# %%
person={'name':'Sam','city':'Chennai'}
print(person['name'])

# %% [markdown]
# ### Exercise
# Practice **Accessing Values**.

# %%
# Write your solution here

# %% [markdown]
# ## Using get()
#
# Safely retrieve values.

# %%
person={'name':'Sam'}
print(person.get('age','Not Found'))

# %% [markdown]
# ### Exercise
# Practice **Using get()**.

# %%
# Write your solution here

# %% [markdown]
# ## Updating Values
#
# Change existing values.

# %%
d={'age':20}
d['age']=21
print(d)

# %% [markdown]
# ### Exercise
# Practice **Updating Values**.

# %%
# Write your solution here

# %% [markdown]
# ## Adding Items
#
# Add new key-value pairs.

# %%
d={'name':'A'}
d['city']='Madurai'
print(d)

# %% [markdown]
# ### Exercise
# Practice **Adding Items**.

# %%
# Write your solution here

# %% [markdown]
# ## Removing Items
#
# pop(), del, clear().

# %%
d={'a':1,'b':2}
d.pop('a')
print(d)

# %% [markdown]
# ### Exercise
# Practice **Removing Items**.

# %%
# Write your solution here

# %% [markdown]
# ## Dictionary Methods
#
# keys(), values(), items().

# %%
d={'x':1,'y':2}
print(d.keys())
print(d.values())
print(d.items())

# %% [markdown]
# ### Exercise
# Practice **Dictionary Methods**.

# %%
# Write your solution here

# %% [markdown]
# ## Looping
#
# Iterate through dictionaries.

# %%
d={'A':90,'B':80}
for k,v in d.items():
    print(k,v)

# %% [markdown]
# ### Exercise
# Practice **Looping**.

# %%
# Write your solution here

# %% [markdown]
# ## Nested Dictionaries
#
# Dictionary inside dictionary.

# %%
students={'s1':{'name':'John','age':20}}
print(students['s1']['name'])

# %% [markdown]
# ### Exercise
# Practice **Nested Dictionaries**.

# %%
# Write your solution here

# %% [markdown]
# ## Dictionary Comprehension
#
# Create dictionaries compactly.

# %%
sq={x:x*x for x in range(5)}
print(sq)

# %% [markdown]
# ### Exercise
# Practice **Dictionary Comprehension**.

# %%
# Write your solution here

# %% [markdown]
# ## Membership
#
# Check keys.

# %%
d={'a':1}
print('a' in d)

# %% [markdown]
# ### Exercise
# Practice **Membership**.

# %%
# Write your solution here

# %% [markdown]
# ## Mini Project
# Student Record Management using Dictionary

# %%
students={
'101':{'name':'Alice','marks':90},
'102':{'name':'Bob','marks':85}
}
for sid,info in students.items():
    print(sid,info['name'],info['marks'])

# %% [markdown]
# ## Quiz
# 1. What is a dictionary?
# 2. Difference between keys() and values()?
# 3. What does items() return?
# 4. What is dictionary comprehension?
# 5. How do you update a value?
