# %% [markdown]
# # Python Programming for Beginners
#
# ## Module 1: Introduction to Python Programming
#
# ### Learning Objectives

# %% [markdown]
# ## Learning Objectives
#
# After completing this notebook, you will be able to:
#
# - Understand Python syntax
# - Create and use variables
# - Identify and work with different data types
# - Accept user input and display output
# - Write conditional statements using `if`, `elif`, and `else`
# - Use `for` and `while` loops
# - Create lists using list comprehensions
# - Solve basic Python programming problems

# %% [markdown]
# #1.What is Python?
#
# Python is a high-level, interpreted, general-purpose programming language used to write programs and build applications. It is known for its simple and readable syntax, making it one of the best languages for beginners.

# %% [markdown]
# #2.Who created Python?
# Python was created by Guido van Rossum.
#
# #3.When was Python created?
# Development started in 1989
# First official release: 1991
#
# #4.Why was Python created?
# Python was created to:
# Make programming easy to learn
# Improve code readability
# Reduce the amount of code needed
# Increase programmer productivity

# %% [markdown]
# #Why should you learn Python?
#
# Python is:
# Easy to learn
# Beginner-friendly
# Powerful and versatile
# Free and open source
# Cross-platform (Windows, Linux, macOS)
# In high demand across many industries
#
#
# #Where is Python used?
#
# Python is widely used in:
#
# 🤖 Artificial Intelligence (AI)
# 🧠 Machine Learning (ML)
# 📊 Data Science
# 📈 Data Analytics
# 🌐 Web Development
# ⚙️ Automation & Scripting
# 🔒 Cybersecurity
# ☁️ Cloud Computing
# 🗄️ Data Engineering
# 🎮 Game Development
# 🖥️ Desktop Applications
# 🤖 Robotics
# 📡 Internet of Things (IoT)
#
# #Who uses Python?
#
# Python is used by:
#
# Students
# Software Developers
# Data Analysts
# Data Scientists
# Data Engineers
# AI & ML Engineers
# Web Developers
# Automation Engineers
# Cybersecurity Professionals
# Researchers
# Scientists
# Businesses and Startups

# %% [markdown]
# #How does Python work?
#
# You write Python code (.py file).
# The Python interpreter reads the code.
# It converts the code into bytecode.
# The Python Virtual Machine (PVM) executes the bytecode.
# The computer displays the output.
#
# #What are the main features of Python?
#
# Simple and readable syntax
# Interpreted language
# High-level language
# Object-Oriented Programming (OOP) support
# Dynamically typed
# Large standard library
# Automatic memory management
# Huge community support
#
#
#
# #What can you build with Python?
#
# You can build:
#
# Websites
# AI Chatbots
# Machine Learning models
# Data Analysis dashboards
# Automation scripts
# Games
# Desktop applications
# APIs
# Data pipelines
# Cloud applications

# %% [markdown]
# # Introduction to Python
#
# Read the explanation, run the code, then complete the exercise below.

# %%
print('Hello, Python!')
# Out:
# Hello, Python!

# %% [markdown]
# ## Exercise
# Print your own name.

# %% [markdown]
# ## Comments

# %%
# This is a comment
print('Done')
# Out:
# Done

# %%
"""Multi-line
comment"""

# %% [markdown]
# # Variables
#
# Read the explanation, run the code, then complete the exercise below.

# %%
name='Alice'
age=20
print(name,age)

# %% [markdown]
# ## Creating Variables
#
# Assign using =

# %%
a=5
b=3.14
c=True

# %% [markdown]
# ### Practice
# Write your own example for **Creating Variables**.

# %% [markdown]
# ## Naming Rules
#
# Use meaningful names.

# %%
student_name='Sam'
_age=20

# %% [markdown]
# ### Practice
# Write your own example for **Naming Rules**.

# %% [markdown]
# ## Multiple Assignment
#
# Assign multiple values.

# %%
x,y,z=1,2,3
print(x,y,z)
# Out:
# 1 2 3

# %% [markdown]
# ## Dynamic Typing
#
# Type can change.

# %%
x=10
x='Ten'
print(type(x))

# %% [markdown]
# ### Practice
# Write your own example for **Multiple Assignment**.

# %% [markdown]
# # Data Types
#
# Read the explanation, run the code, then complete the exercise below.

# %%
x=10 #Integers
pi=3.14 #float
text='Hi' #String
flag=True #Booleans
print(type(x),type(pi),type(text),type(flag))

# %% [markdown]
# **Exercise:** Modify the code and observe the output.

# %% [markdown]
# ## Type Conversion
#
# Convert between types.

# %%
print(int('10'))
print(float(5))

# %% [markdown]
# # Input and Output
#
# Read the explanation, run the code, then complete the exercise below.

# %%
name=input('Enter name: ')
print('Hello',name)

# %% [markdown]
# **Exercise:** Modify the code and observe the output.

# %% [markdown]
# ## Formatted Output
#
# Use f-strings.

# %%
name='Sam';age=20
print(f'{name} is {age}')

# %% [markdown]
# ## Arithmetic Operators
#
# Addition, subtraction, multiplication, division, modulus, floor division and exponentiation.

# %%
a=15
b=4
print("Addition:",a+b)
print("Subtraction:",a-b)
print("Multiplication:",a*b)
print("Division:",a/b)
print("Modulus:",a%b)
print("Floor Division:",a//b)
print("Power:",a**b)

# %% [markdown]
# ## Comparison Operators
#
# Compare two values and return True or False.

# %%
x=10
y=20
print(x==y)
print(x!=y)
print(x<y)
print(x>=y)

# %% [markdown]
# ## Logical Operators
#
# Use and, or, not.

# %%
age=22
salary=40000
print(age>18 and salary>30000)
print(age<18 or salary>30000)
print(not(age<18))

# %% [markdown]
# ## Assignment Operators
#
# Update variable values.

# %%
x=10
x+=5
print(x)
x*=2
print(x)

# %% [markdown]
# # Conditionals
#
# Read the explanation, run the code, then complete the exercise below.

# %% [markdown]
# ## if Statement
#
# Execute code when a condition is True.

# %%
age=20
if age>=18:
    print('Eligible to vote')

# %% [markdown]
# ## if...else
#
# Choose between two paths.

# %%
num=7
if num%2==0:
    print('Even')
else:
    print('Odd')

# %% [markdown]
# ## if...elif...else
#
# Handle multiple conditions.

# %%
marks=82
if marks>=90:
 print('A')
elif marks>=75:
 print('B')
elif marks>=50:
 print('C')
else:
 print('Fail')

# %% [markdown]
# ## Nested if
#
# Place one if inside another.

# %%
age=22
citizen=True
if age>=18:
    if citizen:
        print('Eligible')

# %% [markdown]
# # For Loop
#
# Read the explanation, run the code, then complete the exercise below.

# %%
for i in range(5):
    print(i)

# %% [markdown]
# ## Looping Through Lists
#
# Iterate over list items.

# %%
fruits=['Apple','Banana','Orange']
for f in fruits:
    print(f)

# %% [markdown]
# # While Loop
#
# Read the explanation, run the code, then complete the exercise below.

# %%
i=1
while i<=5:
    print(i)
    i+=1

# %% [markdown]
# ## break
#
# Exit loop immediately.

# %%
for i in range(10):
    if i==5:
        break
    print(i)

# %% [markdown]
# ## continue
#
# Skip current iteration.

# %%
for i in range(6):
    if i==3:
        continue
    print(i)

# %% [markdown]
# ## pass
#
# Placeholder statement.

# %%
for i in range(3):
    pass
print('Done')

# %% [markdown]
# # Practical Lab
#
# Complete the following exercises:
#
# 1. Hello World
#
# 2. Name and Age
#
# 3. Calculator
#
# 4. Even or Odd
#
# 5. Largest Number
#
# 6. Multiplication Table
#
# 7. Sum of First 100 Numbers
#
# 8. Grade Calculator
#
# 9. Factorial
#
# 10. Fibonacci Series
#
# 11. Reverse a String
#
# 12. Count Vowels

# %% [markdown]
# ## Debugging Exercise
#
# Find and fix errors.

# %%
# Fix the following:
# print("Hello)
# x==10
# if x>5
#     print(x)
