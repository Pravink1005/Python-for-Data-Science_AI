# %% [markdown]
# ## Python Data Structures: Lists

# %% [markdown]
# ## Learning Objectives
# - Create and manipulate lists
# - Use common list methods
# - Iterate through lists
# - Write list comprehensions

# %% [markdown]
# ## Introduction
#
# Lists are ordered, mutable collections.

# %%
fruits=['Apple','Banana','Orange']
print(fruits)

# %% [markdown]
# ### Exercise
# Modify the example.

# %%
# Your code

# %% [markdown]
# ## Creating Lists
#
# Create lists.

# %%
a=[]
b=[1,2,3]
print(a,b)

# %% [markdown]
# ### Exercise
# Modify the example.

# %%
# Your code

# %% [markdown]
# ## Indexing
#
# Access items.

# %%
nums=[10,20,30]
print(nums[0],nums[-1])

# %% [markdown]
# ### Exercise
# Modify the example.

# %%
# Your code

# %% [markdown]
# ## Slicing
#
# Slice lists.

# %%
nums=[1,2,3,4,5]
print(nums[1:4])

# %% [markdown]
# ### Exercise
# Modify the example.

# %%
# Your code

# %% [markdown]
# ## Updating
#
# Update items.

# %%
nums=[1,2,3]
nums[1]=20
print(nums)

# %% [markdown]
# ### Exercise
# Modify the example.

# %%
# Your code

# %% [markdown]
# ## append
#
# Append item.

# %%
l=[1,2]
l.append(3)
print(l)

# %% [markdown]
# ### Exercise
# Modify the example.

# %%
# Your code

# %% [markdown]
# ## insert
#
# Insert item.

# %%
l=[1,3]
l.insert(1,2)
print(l)

# %% [markdown]
# ### Exercise
# Modify the example.

# %%
# Your code

# %% [markdown]
# ## extend
#
# Extend list.

# %%
a=[1,2]
a.extend([3,4])
print(a)

# %% [markdown]
# ### Exercise
# Modify the example.

# %%
# Your code

# %% [markdown]
# ## remove/pop
#
# Remove items.

# %%
l=[1,2,3]
l.remove(2)
print(l)
print(l.pop())

# %% [markdown]
# ### Exercise
# Modify the example.

# %%
# Your code

# %% [markdown]
# ## sort/reverse
#
# Sort and reverse.

# %%
l=[3,1,2]
l.sort();print(l)
l.reverse();print(l)

# %% [markdown]
# ### Exercise
# Modify the example.

# %%
# Your code

# %% [markdown]
# ## Looping
#
# Loop over list.

# %%
for x in ['A','B']:
    print(x)

# %% [markdown]
# ### Exercise
# Modify the example.

# %%
# Your code

# %% [markdown]
# ## Membership
#
# Check membership.

# %%
print('A' in ['A','B'])

# %% [markdown]
# ### Exercise
# Modify the example.

# %%
# Your code

# %% [markdown]
# ## Nested Lists
#
# Nested.

# %%
m=[[1,2],[3,4]]
print(m[1][0])

# %% [markdown]
# ### Exercise
# Modify the example.

# %%
# Your code

# %% [markdown]
# ## List Comprehension
#
# Create squares.

# %%
sq=[x*x for x in range(5)]
print(sq)

# %% [markdown]
# ### Exercise
# Modify the example.

# %%
# Your code

# %% [markdown]
# ## Mini Project

# %%
marks=[80,90,70]
print(sum(marks),sum(marks)/len(marks))
