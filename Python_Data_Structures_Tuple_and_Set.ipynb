# %% [markdown]
# ## Python Tuples and Sets

# %% [markdown]
# ## Learning Objectives
# - Understand tuples and sets
# - Learn tuple packing/unpacking
# - Perform set operations
# - Practice with tuple and set methods

# %% [markdown]
# ## Introduction to Tuples
#
# Tuples are ordered and immutable.

# %%
t=(10,20,30)
print(t)

# %% [markdown]
# ### Exercise
# Practice **Introduction to Tuples** with your own example.

# %%
# Write your solution here

# %% [markdown]
# ## Creating Tuples
#
# Create empty, single and multiple item tuples.

# %%
a=()
b=(5,)
c=(1,2,3)
print(a,b,c)

# %% [markdown]
# ### Exercise
# Practice **Creating Tuples** with your own example.

# %%
# Write your solution here

# %% [markdown]
# ## Tuple Indexing
#
# Access tuple elements.

# %%
t=('A','B','C')
print(t[0],t[-1])

# %% [markdown]
# ### Exercise
# Practice **Tuple Indexing** with your own example.

# %%
# Write your solution here

# %% [markdown]
# ## Tuple Slicing
#
# Slice tuples.

# %%
t=(1,2,3,4,5)
print(t[1:4])

# %% [markdown]
# ### Exercise
# Practice **Tuple Slicing** with your own example.

# %%
# Write your solution here

# %% [markdown]
# ## Tuple Packing
#
# Pack multiple values.

# %%
person=('John',25,'India')
print(person)

# %% [markdown]
# ### Exercise
# Practice **Tuple Packing** with your own example.

# %%
# Write your solution here

# %% [markdown]
# ## Tuple Unpacking
#
# Unpack tuple values.

# %%
name,age,country=('John',25,'India')
print(name,age,country)

# %% [markdown]
# ### Exercise
# Practice **Tuple Unpacking** with your own example.

# %%
# Write your solution here

# %% [markdown]
# ## Tuple Methods
#
# count() and index().

# %%
t=(1,2,2,3)
print(t.count(2),t.index(3))

# %% [markdown]
# ### Exercise
# Practice **Tuple Methods** with your own example.

# %%
# Write your solution here

# %% [markdown]
# ## Loop Through Tuple
#
# Iterate over tuples.

# %%
for x in (10,20,30):
    print(x)

# %% [markdown]
# ### Exercise
# Practice **Loop Through Tuple** with your own example.

# %%
# Write your solution here

# %% [markdown]
# ## Introduction to Sets
#
# Sets store unique values.

# %%
s={1,2,3,2}
print(s)

# %% [markdown]
# ### Exercise
# Practice **Introduction to Sets** with your own example.

# %%
# Write your solution here

# %% [markdown]
# ## Adding Items
#
# Use add().

# %%
s={1,2}
s.add(3)
print(s)

# %% [markdown]
# ### Exercise
# Practice **Adding Items** with your own example.

# %%
# Write your solution here

# %% [markdown]
# ## Removing Items
#
# remove(), discard(), pop().

# %%
s={1,2,3}
s.remove(2)
print(s)

# %% [markdown]
# ### Exercise
# Practice **Removing Items** with your own example.

# %%
# Write your solution here

# %% [markdown]
# ## Set Union
#
# Combine sets.

# %%
a={1,2};b={2,3}
print(a|b)

# %% [markdown]
# ### Exercise
# Practice **Set Union** with your own example.

# %%
# Write your solution here

# %% [markdown]
# ## Set Intersection
#
# Common elements.

# %%
a={1,2};b={2,3}
print(a&b)

# %% [markdown]
# ### Exercise
# Practice **Set Intersection** with your own example.

# %%
# Write your solution here

# %% [markdown]
# ## Set Difference
#
# Difference.

# %%
a={1,2};b={2,3}
print(a-b)

# %% [markdown]
# ### Exercise
# Practice **Set Difference** with your own example.

# %%
# Write your solution here

# %% [markdown]
# ## Symmetric Difference
#
# Unique elements.

# %%
a={1,2};b={2,3}
print(a^b)

# %% [markdown]
# ### Exercise
# Practice **Symmetric Difference** with your own example.

# %%
# Write your solution here

# %% [markdown]
# ## Mini Project
# Find common students between two classroom lists using sets.

# %%
class_a={'Alice','Bob','Charlie'}
class_b={'Bob','David','Charlie'}
print("Common:", class_a & class_b)

# %% [markdown]
# ## Quiz
# 1. What is the difference between a list and a tuple?
# 2. Why are sets useful?
# 3. Difference between remove() and discard()?
# 4. What is tuple unpacking?
# 5. Write a union operation example.
